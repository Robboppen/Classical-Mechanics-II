# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.linspace(-2, 2, 100)
x = np.exp(t)
y = np.exp(-t)
plt.plot(x, y, 'b-', label='$xy = 1$')
plt.xlabel('$x$'); plt.ylabel('$y$'); plt.grid(); plt.legend(); plt.show()
